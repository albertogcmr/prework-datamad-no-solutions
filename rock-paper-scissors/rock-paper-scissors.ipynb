# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options = ["stone", "paper", "scissors"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
number_of_games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

def games(number_of_games):
    if number_of_games % 2 == 0:
        games_to_win = number_of_games / 2 + 1
    else:
        games_to_win = (number_of_games - 1) / 2 + 1
    return games_to_win

to_win = games(number_of_games)

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.



def select_option_machine():
    chosen_option_machine = random.choice(options)
    return chosen_option_machine

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

a = "stone"
b = "paper"
c = "scissors"

results =   [[a, b, b],
            [a, c, a],
            [b, c, c]]


def select_option_human():
    chosen_option_human = input("Choose! stone, paper or scissors: ")
    while chosen_option_human not in options:
        chosen_option_human = input("Wrong input. Please choose between stone, paper or scissors: ")
    return chosen_option_human



# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

winning_result = 0

def combat():
    x = select_option_machine()
    y = select_option_human()
    if x == y:
            return 0, x, y
    else:
        for i in range(len(results)):
            if (x == results[i][0] or x == results[i][1]) and (y == results[i][0] or y == results[i][1]):
                winning_result = results[i][2]
                if (winning_result == x):
                    return 1, x, y
                else:
                    return 2, x, y

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def game():
    counter_machine = 0
    counter_human = 0
    for i in range(number_of_games):
        game_result = list(combat())
        if (counter_machine != games(number_of_games) and counter_human != games(number_of_games)):
            if game_result[0] == 0:
                message = "Tie!"
                counter_machine = counter_machine + 1
                counter_human = counter_human + 1
            elif game_result[0] == 1:
                message = "Machine won!"
                counter_machine = counter_machine + 1
            else:
                message = "Human won!"
                counter_human = counter_human + 1
            print("This was round %d. Machine chose %s, human chose %s. %s" % (i+1, game_result[1], game_result[2], message))
            print("Current result: Machine: %d Human: %d" % (counter_machine, counter_human))
            if (counter_machine == games(number_of_games) and counter_machine == counter_human):
                print("Game ended! This was a Tie!")
                break
            else:
                if (counter_machine == games(number_of_games) and counter_machine > counter_human):
                    print("Game ended! Machine won!")
                    break
                elif(counter_machine == games(number_of_games) and counter_machine < counter_human):
                    print("Game ended! Human won!")
                    break
game()
# Create two variables that accumulate the wins of each participant


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Choose! stone, paper or scissors: stone
# This was round 1. Machine chose paper, human chose stone. Machine won!
# Current result: Machine: 1 Human: 0
# Choose! stone, paper or scissors: paper
# This was round 2. Machine chose paper, human chose paper. Tie!
# Current result: Machine: 2 Human: 1
# Choose! stone, paper or scissors: scissors
# This was round 3. Machine chose stone, human chose scissors. Machine won!
# Current result: Machine: 3 Human: 1
# Game ended! Machine won!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def odd_number():
    n = int(input("Introduce and odd number: "))
    while(n % 2 == 0):
        n = int(input("Wrong input, introduce and odd number: "))
    return  n

# Assign a list of 5 possible options.
options = ["stone", "paper", "scissors", "lizard", "spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_number_games = odd_number()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

def games():
    return (max_number_games - 1) / 2 + 1


# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

def select_option_machine():
    return random.choice(options)


# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

def select_option_human():
    chosen_option_human = input("Choose! stone, paper, scissors, lizard, spock: ")
    while chosen_option_human not in options:
        chosen_option_human = input("Wrong input. Please choose between stone, paper, scissors, lizard, spock: ")
    return chosen_option_human


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options

a = "stone"
b = "paper"
c = "scissors"
d = "lizard"
e = "spock"

results =   [[a, b, b],
             [a, c, a],
             [a, d, a],
             [a, e, e],
             [b, c ,c],
             [b, d, d],
             [b, e, b],
             [c, d, c],
             [c, e, e],
             [d, e, e]]

winning_result = 0

def combat():
    x = select_option_machine()
    y = select_option_human()
    if x == y:
            return 0, x, y
    else:
        for i in range(len(results)):
            if (x == results[i][0] or x == results[i][1]) and (y == results[i][0] or y == results[i][1]):
                winning_result = results[i][2]
                if (winning_result == x):
                    return 1, x, y
                else:
                    return 2, x, y

def game():
    counter_machine = 0
    counter_human = 0
    for i in range(max_number_games):
        game_result = list(combat())
        if (counter_machine != games() and counter_human != games()):
            if game_result[0] == 0:
                message = "Tie!"
                counter_machine = counter_machine + 1
                counter_human = counter_human + 1
            elif game_result[0] == 1:
                message = "Machine won!"
                counter_machine = counter_machine + 1
            else:
                message = "Human won!"
                counter_human = counter_human + 1
            print("This was round %d. Machine chose %s, human chose %s. %s" % (i+1, game_result[1], game_result[2], message))
            print("Current result: Machine: %d Human: %d" % (counter_machine, counter_human))
            if (counter_machine == games() and counter_machine == counter_human):
                print("Game ended! This was a Tie!")
                break
            else:
                if (counter_machine == games() and counter_machine > counter_human):
                    print("Game ended! Machine won!")
                    break
                elif(counter_machine == games() and counter_machine < counter_human):
                    print("Game ended! Human won!")
                    break
game()                
                
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

    
# Create two variables that accumulate the wins of each participant


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
    
    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Introduce and odd number: 5
# Choose! stone, paper, scissors, lizard, spock: paper
# This was round 1. Machine chose scissors, human chose paper. Machine won!
# Current result: Machine: 1 Human: 0
# Choose! stone, paper, scissors, lizard, spock: spock
# This was round 2. Machine chose spock, human chose spock. Tie!
# Current result: Machine: 2 Human: 1
# Choose! stone, paper, scissors, lizard, spock: spock
# This was round 3. Machine chose paper, human chose spock. Machine won!
# Current result: Machine: 3 Human: 1
# Game ended! Machine won!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
